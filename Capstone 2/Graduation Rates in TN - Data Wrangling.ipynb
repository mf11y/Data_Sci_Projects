# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/18_19_Grad_rate_district.csv')

# %%
demo = pd.read_excel('./data/18_19_Demo.xlsx')

# %%
data
# Out:
#       year  system                  system_name  school  \
# 0     2019      10              Anderson County       2
# 1     2019      10              Anderson County       2
# 2     2019      10              Anderson County       2
# 3     2019      10              Anderson County       2
# 4     2019      10              Anderson County       2
# ...    ...     ...                          ...     ...
# 7131  2019     985  Achievement School District    8140
# 7132  2019     985  Achievement School District    8140
# 7133  2019     985  Achievement School District    8140
# 7134  2019     985  Achievement School District    8140
# 7135  2019     985  Achievement School District    8140
#
#                       school_name                        subgroup  \
# 0     Anderson County High School                    All Students
# 1     Anderson County High School                           Asian
# 2     Anderson County High School       Black or African American
# ...

# %%
data = data.loc[data.subgroup == 'All Students']

# %%
data.grad_rate.unique()
# Out:
# array(['96.1', '95.2', '*', '92.1', '98.2', '88.7', '91.4', '**', '94.3',
#        '93.3', '92.8', '98.8', '94.5', '92.3', '92.7', '95.8', '87.5',
#        '90', '91.1', '92.2', '91', '97.7', '97.3', '91.5', '83.7', '87.3',
#        '88.9', '91.2', '94', '91.8', '95.9', '90.7', '97.8', '92.6',
#        '92.5', '90.8', '96.4', '94.8', '78.5', '77.8', '72.8', '84.5',
#        '74.7', '83.3', '82.1', '88.3', '20', '77.2', '80.4', '64', '69.3',
#        '66.9', '85.5', '76.8', '83.8', '88.4', '83.9', '90.3', '93.1',
#        '91.3', '93.2', '94.4', '95', '96.7', '88.1', '98.6', '84.9',
#        '97.9', '95.5', '90.5', '93.7', '94.7', '93.6', '88.5', '97.4',
#        '90.6', '93.9', '83.2', '94.1', '88.8', '85.9', '85.8', '63.1',
#        '85.7', '89.9', '77.9', '96.5', '92', '95.3', '95.1', '94.2',
#        '94.6', '91.7', '98.5', '96.3', '81.1', '97.1', '93.8', '82',
#        '85.6', '93.4', '18.8', '90.1', '72', '93.5', '99', '96.6', '98.4',
# ...

# %%
data = data.loc[~data.grad_rate.isin(['*', '**'])]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 7118
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         333 non-null    int64
#  1   system       333 non-null    int64
#  2   system_name  333 non-null    object
#  3   school       333 non-null    int64
#  4   school_name  333 non-null    object
#  5   subgroup     333 non-null    object
#  6   grad_cohort  333 non-null    int64
#  7   grad_count   333 non-null    object
#  8   grad_rate    333 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 26.0+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 7118
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         333 non-null    int64
#  1   system       333 non-null    int64
#  2   system_name  333 non-null    object
#  3   school       333 non-null    int64
#  4   school_name  333 non-null    object
#  5   subgroup     333 non-null    object
#  6   grad_cohort  333 non-null    int64
#  7   grad_count   333 non-null    object
#  8   grad_rate    333 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 26.0+ KB

# %%
data.grad_rate = data.grad_rate.astype(float)

# %%
data = data[['system','school','grad_rate']].copy()

# %%
data.rename(columns={'system':'DISTRICT_ID', 'school':'SCHOOL_ID'}, inplace=True)

# %%
data
# Out:
#       DISTRICT_ID  SCHOOL_ID  grad_rate
# 0              10          2       96.1
# 17             10         25       95.2
# 46             12         35       92.1
# 66             20         13       98.2
# 85             20         20       88.7
# ...           ...        ...        ...
# 7051          985         45       11.8
# 7069          985         50       11.0
# 7084          985       8055       80.5
# 7101          985       8065       73.0
# 7118          985       8140       60.4
#
# [333 rows x 3 columns]

# %%
demo = demo[['DISTRICT_ID',
             'SCHOOL_ID',
             'AVERAGE_DAILY_MEMBERSHIP',
             'TOTAL', 
             'ECONOMICALLY_DISADVANTAGED',
             'FEMALE','HISPANIC_FEMALE','ASIAN_FEMALE','AFRICAN_AMERICAN_FEMALE', 'WHITE_FEMALE',
             'MALE','AFRICAN_AMERICAN_MALE','WHITE_MALE', 'ASIAN_MALE', 'HISPANIC_MALE', 
             'AFRICAN_AMERICAN',
             'ASIAN', 
             'HISPANIC', 
             'WHITE',
             'STUDENTS_WITH_DISABILITIES',
             'NATIVE_AMERICAN',
             'HAWAIIAN_PACISLD', 
             'HAWAIIAN_PACISLD_FEMALE', 'HAWAIIAN_PACISLD_MALE', 
             'NATIVE_AMERICAN_FEMALE', 'NATIVE_AMERICAN_MALE']]
demo
# Out:
#       DISTRICT_ID  SCHOOL_ID  AVERAGE_DAILY_MEMBERSHIP  TOTAL  \
# 0             985       8050                     607.0    612
# 1             985       8025                     530.0    544
# 2             985       8024                     238.0    239
# 3             985       8005                     310.0    305
# 4             985       8010                     380.0    375
# ...           ...        ...                       ...    ...
# 1751          950         60                     558.0    571
# 1752          950         95                     301.0    300
# 1753          950         65                     799.0    794
# 1754          950         33                    1408.0   1408
# 1755          950         73                    1907.0   1935
#
#       ECONOMICALLY_DISADVANTAGED  FEMALE  HISPANIC_FEMALE  ASIAN_FEMALE  \
# 0                            436     315               14             3
# 1                            429     281                3             0
# ...

# %%
demo.loc[:, 'ECONOMICALLY_DISADVANTAGED':].describe().loc['min':'max']
# Out:
#      ECONOMICALLY_DISADVANTAGED   FEMALE  HISPANIC_FEMALE  ASIAN_FEMALE  \
# min                         0.0     0.00              0.0           0.0
# 25%                       103.0   157.00              5.0           0.0
# 50%                       165.5   231.00             13.0           2.0
# 75%                       256.0   336.25             35.0           6.0
# max                       935.0  1384.00            331.0         155.0
#
#      AFRICAN_AMERICAN_FEMALE  WHITE_FEMALE     MALE  AFRICAN_AMERICAN_MALE  \
# min                      0.0           0.0     0.00                   0.00
# 25%                      7.0          64.0   167.75                   7.00
# 50%                     25.0         145.0   243.00                  27.00
# 75%                     98.0         228.0   347.00                  99.25
# max                    871.0         945.0  1389.00                 769.00
#
#      WHITE_MALE  ASIAN_MALE  ...  ASIAN  HISPANIC    WHITE  \
# ...

# %%
demo = demo.loc[:, 'DISTRICT_ID':'WHITE']

# %%
grad_demo = pd.merge(data,demo, how='inner', on=['SCHOOL_ID', 'DISTRICT_ID'])

# %%
#grad_demo.loc[:, 'ECONOMICALLY_DISADVANTAGED':] = grad_demo.loc[:, 'ECONOMICALLY_DISADVANTAGED':].div(grad_demo.TOTAL,axis=0)

# %%
#grad_demo.grad_rate = grad_demo.grad_rate / 100

# %%
grad_demo
# Out:
#      DISTRICT_ID  SCHOOL_ID  grad_rate  AVERAGE_DAILY_MEMBERSHIP  TOTAL  \
# 0             10          2       96.1                    1083.0   1075
# 1             10         25       95.2                    1107.0   1120
# 2             12         35       92.1                    1399.0   1406
# 3             20         13       98.2                     488.0    481
# 4             20         20       88.7                    1483.0   1506
# ..           ...        ...        ...                       ...    ...
# 325          985         45       11.8                     153.0    174
# 326          985         50       11.0                     189.0    173
# 327          985       8055       80.5                     511.0    520
# 328          985       8065       73.0                     490.0    513
# 329          985       8140       60.4                     435.0    461
#
#      ECONOMICALLY_DISADVANTAGED  FEMALE  HISPANIC_FEMALE  ASIAN_FEMALE  \
# ...

# %%
grad_demo.describe()
# Out:
#        DISTRICT_ID    SCHOOL_ID   grad_rate  AVERAGE_DAILY_MEMBERSHIP  \
# count   330.000000   330.000000  330.000000                327.000000
# mean    534.581818   742.054545   89.022727                851.003058
# std     285.901243  1987.130467   13.185372                564.318610
# min      10.000000     1.000000   11.000000                 17.000000
# 25%     280.000000    25.000000   88.325000                437.000000
# 50%     575.000000    50.000000   93.200000                704.000000
# 75%     792.000000   118.750000   95.700000               1158.000000
# max     985.000000  8275.000000   99.000000               2748.000000
#
#              TOTAL  ECONOMICALLY_DISADVANTAGED       FEMALE  HISPANIC_FEMALE  \
# count   330.000000                  330.000000   330.000000        330.00000
# mean    870.854545                  251.690909   425.312121         39.80303
# std     574.124435                  178.590619   283.854756         58.11398
# ...
